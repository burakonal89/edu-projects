# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
N = 1000
x = np.random.beta(48, 52, size=int(N))
a = plt.hist(x, bins=20, edgecolor='k', linewidth=2, density=True)

# %%
sorted_x = sorted(x, reverse=True)
mu = np.zeros(shape=(int(N)))
for i in range(int(N)):
    mu[i] = np.mean(sorted_x[0:i+1])

# %%
plt.plot(np.arange(N)/N, mu*100)

# %%
mu
# Out:
# array([[ 5.,  5.,  5., ...,  5.,  5.,  5.]])

# %%
plt.plot(k[1], k[0]/N)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-0faed41f085d> in <module>()
# ----> 1 plt.plot(k[1], k[0]/N)
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3259                       mplDeprecation)
#    3260     try:
# -> 3261         ret = ax.plot(*args, **kwargs)
#    3262     finally:
#    3263         ax._hold = washold
#
# ~/anaconda/envs/python3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ...

# %% [markdown]
# ### Parsing Election Results

# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.sabah.com.tr/secim/24-haziran-2018-secim-sonuclari/kastamonu-secim-sonuclari")

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <!-- Meta -->
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="all" name="robots"/>
#   <meta content="" name="csrf-token"/>
#   <title>
#    Kastamonu Seçim Sonuçları - 24 Haziran 2018 Genel Seçimleri
#   </title>
#   <meta content="Kastamonu Seçim Sonuçları - 24 Haziran 2018 Genel Seçimleri" name="description"/>
#   <link href="https://i.tmgrup.com.tr/secim/24-haziran-2018-secim-sonuclari/img/favicon.ico" rel="icon"/>
#   <!-- HTML5 elements and media queries Support for IE8 : HTML5 shim and Respond.js -->
#   <!--[if lt IE 9]>
#             <script src="/js/html5shiv.js"></script>
#         <![endif]-->
#   <script>
#    var site_language = "tr";
#   </script>
# ...

# %%
import numpy as np

# %%
1-1/(1+np.exp(-6+0.05*40+3.5))
# Out:
# 0.37754066879814541
