# %%
import pandas as pd
import datetime
import re
pd.set_option("display.max_colwidth", 1000)
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import datetime
import seaborn as sn

# %%
def pre_process(f_in, f_out):
    df = pd.DataFrame(columns=["date", "time", "name", "message"])
    info_pattern = re.compile(r'(\d\d/\d\d/\d\d\d\d),\s(\d\d:\d\d:\d\d):\s')
    iter_ = 0
    with open(f_in, "r") as f_in, open(f_out, "w") as f_out:
        for line in f_in:
            line = line.strip()
            info = info_pattern.match(line)
            if info:
                date = info.group(1)
                time = info.group(2)
                body = line[21:]
                if ":" not in body:
                    name = "info_message"
                    message = body.strip()
                else:
                    name, message = body.split(":", 1)
                    name = name.strip()
                    message = message.strip()
                # print iter_, message
                text = date+" "+time+"\t"+name+"\t"+message+"\n"
                f_out.write(text)

# %%
pre_process("_chat.txt", "chat_bros.csv")
pre_process("_chat_p.txt", "chat_pijler.csv")

# %%
df = pd.read_csv("chat_bros.csv", 
                 sep="\t", 
                 names=["date-time", "name", "message"])
# converting date-time to date time object
df['date-time'] = df['date-time'].apply(lambda x: datetime.datetime.strptime(x, "%d/%m/%Y %H:%M:%S"))
# changing unknown numbers or duplicates
df["name"] = df["name"].apply(lambda x: "Erdem Kulahci" if "829" in x else x)

# %%
df["name"] = df["name"].apply(lambda x: "Emre İşeri" if "‪019‬" in x else x)

# %%
df_groupped_day = df.set_index('date-time').groupby(pd.TimeGrouper("D")).count()
df_groupped_week = df.set_index('date-time').groupby(pd.TimeGrouper("W")).count()
df_groupped_month = df.set_index('date-time').groupby(pd.TimeGrouper("M")).count()

# %%
plt.plot_date(df_groupped_day.index, 
              df_groupped_day["message"], 
              fmt="-")
plt.title("Daily # of messages")

# %%
N = 14 # 2 weeks window
plt.plot_date(df_groupped_day.index, 
              np.convolve(df_groupped_day["message"], np.ones((N,))/N, mode='same'), 
              fmt="-")
plt.title("Daily # of messages - Moving Average - 14 days")
df_groupped_day.iloc[np.argmax(np.convolve(df_groupped_day["message"], np.ones((N,))/N, mode='same'))]
# Out:
# name       565
# message    565
# Name: 2016-05-17 00:00:00, dtype: int64

# %%
plt.plot_date(df_groupped_week.index, 
              df_groupped_week["message"], 
              fmt="-")
plt.title("Weekly # of messages")

# %%
plt.plot_date(df_groupped_month.index, 
              df_groupped_month["message"], 
              fmt="-")
plt.title("Monthly # of messages")

# %%
df_groupped_week_names = df.set_index('date-time').groupby(by=[pd.TimeGrouper("W"), "name"]).count().reset_index()
df_groupped_week_names
# Out:
#      date-time                  name  message
# 0   2015-07-26                 Burak        1
# 1   2015-07-26         Caglar Keskin        4
# 2   2015-07-26         Gökhan Bestel       10
# 3   2015-07-26     Sabri Uğur Sönmez       23
# 4   2015-07-26      Seyda Can Yılmaz        4
# 5   2015-07-26          info_message        3
# 6   2015-08-02                 Burak      118
# 7   2015-08-02         Caglar Keskin      108
# 8   2015-08-02         Gökhan Bestel       36
# 9   2015-08-02        Halil Burak Oz       55
# 10  2015-08-02  Halit Sinan Yıldırım       78
# 11  2015-08-02    Mehmet Ihsan Orgut       15
# 12  2015-08-02     Sabri Uğur Sönmez      177
# 13  2015-08-02      Seyda Can Yılmaz       64
# 14  2015-08-02          Ömer Özkiper       28
# 15  2015-08-09                 Burak       77
# 16  2015-08-09         Caglar Keskin       16
# 17  2015-08-09         Gökhan Bestel       24
# 18  2015-08-09        Halil Burak Oz       32
# 19  2015-08-09  Halit Sinan Yıldırım       23
# 20  2015-08-09     Sabri Uğur Sönmez      167
# 21  2015-08-09      Seyda Can Yılmaz       32
# 22  2015-08-09          info_message        2
# 23  2015-08-09          Ömer Özkiper       50
# 24  2015-08-16                 Burak      118
# 25  2015-08-16         Caglar Keskin       66
# 26  2015-08-16         Gökhan Bestel       14
# 27  2015-08-16        Halil Burak Oz       69
# 28  2015-08-16  Halit Sinan Yıldırım       15
# 29  2015-08-16     Sabri Uğur Sönmez       63
# ..         ...                   ...      ...
# 910 2017-02-26      Seyda Can Yılmaz       16
# 911 2017-02-26           Yigit Aykan      198
# 912 2017-03-05                 Burak        1
# 913 2017-03-05          info_message        1
# 914 2017-04-30             Alp Özgen        8
# 915 2017-04-30                 Burak        3
# 916 2017-04-30         Erdem Kulahci        8
# 917 2017-04-30        Halil Burak Oz        1
# 918 2017-04-30  Halit Sinan Yıldırım       12
# 919 2017-04-30         Mustafa Yahsi        6
# 920 2017-04-30     Sabri Uğur Sönmez       11
# 921 2017-04-30          info_message        7
# 922 2017-07-02             Alp Özgen       31
# 923 2017-07-02                 Burak       39
# 924 2017-07-02         Caglar Keskin       13
# 925 2017-07-02         Mustafa Yahsi       56
# 926 2017-07-02     Sabri Uğur Sönmez       61
# 927 2017-07-02      Seyda Can Yılmaz       10
# 928 2017-07-02          info_message        3
# 929 2017-07-09             Alp Özgen       26
# 930 2017-07-09                 Burak       82
# 931 2017-07-09         Caglar Keskin       45
# 932 2017-07-09         Gökhan Bestel       87
# 933 2017-07-09        Halil Burak Oz        2
# 934 2017-07-09  Halit Sinan Yıldırım        4
# 935 2017-07-09         Mustafa Yahsi       64
# 936 2017-07-09     Sabri Uğur Sönmez       83
# 937 2017-07-09      Seyda Can Yılmaz       16
# 938 2017-07-09           Yigit Aykan       22
# 939 2017-07-09    ‪+46 72 019 01 98‬        4
#
# [940 rows x 3 columns]

# %%
f, axarr = plt.subplots(len(names), 
                        sharex=True, 
                        figsize=(40,30))
x_axis = df_groupped_week_names["date-time"].unique()
names = df_groupped_week_names["name"].unique()
for count, name in enumerate(names):
    temp = df_groupped_week_names[df_groupped_week_names["name"]==name].set_index("date-time")
    temp = temp.reindex(x_axis, fill_value=0)
    axarr[count].plot_date(x_axis, 
                  temp["message"], 
                  "-")
    axarr[count].set_title("name")
plt.figure(figsize=(30,40))

# %%
names
# Out:
# array(['Burak', 'Caglar Keskin', 'G\xc3\xb6khan Bestel',
#        'Sabri U\xc4\x9fur S\xc3\xb6nmez', 'Seyda Can Y\xc4\xb1lmaz',
#        'info_message', 'Halil Burak Oz',
#        'Halit Sinan Y\xc4\xb1ld\xc4\xb1r\xc4\xb1m', 'Mehmet Ihsan Orgut',
#        '\xc3\x96mer \xc3\x96zkiper', 'Yigit Aykan', 'Mustafa Yahsi',
#        'Emre \xc4\xb0\xc5\x9feri', 'Erdem Kulahci', 'Alp \xc3\x96zgen',
#        '\xe2\x80\xaa+46\xc2\xa072\xc2\xa0019\xc2\xa001\xc2\xa098\xe2\x80\xac'], dtype=object)

# %%
temp = df_groupped_day_names[df_groupped_day_names["name"]==name].set_index("date-time")
temp = temp.reindex(x_axis, fill_value=0)

# %%
plt.plot_date(x_axis, 
              temp["message"],
             )
